# %%
from pathlib import Path
import fitz

# %%
def load_pdf(path: str | Path) -> dict:
    pages = []
    doc = fitz.open(path)
    metadata = doc.metadata or {}
    title = metadata.get("title")
    if title:
        title = title.strip()
    else:
        title = Path(path).stem
    for i, page in enumerate(doc):
        text = page.get_text().encode("utf8")
        pages.append({
            "page": i + 1,
            "text": text
        })
    return {
        "source_path": str(path),
        "file_type": "pdf",
        "title": title,
        "pages": pages
    }

# %%
p = Path("../data/raw/2502.01906v2.pdf")

# %%
p.stem
# Out:
# '2502.01906v2'

# %%
pdf = load_pdf(p)

# %%
pdf["source_path"]
# Out:
# '../data/raw/2502.01906v2.pdf'

# %%
def load_markdown(path: str | Path) -> dict:
    text = Path(path).read_text(encoding="utf8", errors="ignore")
    return {
        "source_path": str(path),
        "file_type": "md",
        "title": Path(path).stem,
        "pages": [{"page": 1, "text": text}]
    }

# %%
m = Path("../data/raw/moegal_readme.md")

# %%
md = load_markdown(m)

# %%
md["source_path"]
# Out:
# '../data/raw/moegal_readme.md'
